# %%
a = 5

# %%
a
# Out:
# 5

# %%
a = 10

# %%
a
# Out:
# 10

# %%
a+a
# Out:
# 20

# %%
a
# Out:
# 10

# %%
a = a + a

# %%
a
# Out:
# 320

# %%
type(a)
# Out:
# int

# %%
a = 30.1

# %%
type(a)
# Out:
# float

# %%
my_income = 100

tax_rate = 0.1

my_taxes = my_income * tax_rate

# %%
my_taxes
# Out:
# 10.0

# %%
23 % 2
# Out:
# 1

# %%
2 ** 3
# Out:
# 8

# %%
2 + 10 * 10 + 3
# Out:
# 105

# %%
(2+10) * (10 + 3)
# Out:
# 156

# %%
x = "25"
y = 25
z = 25.0

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
number = int(input("give a number"))

print(number+10)
# Out:
# give a number 9
# 19

# %%
17/3
# Out:
# 5.666666666666667

# %%
17%3
# Out:
# 2

# %%
round(17/3)
print(17//3)
# Out:
# 5

# %%
a = 5
b = 9

# %%
a, b = b, a

# %%
a
# Out:
# 9

# %%
b
# Out:
# 5

# %%
x = 42

print(f"The result is: {x}")
# Out:
# The result is: 42
